# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import os

# %%
data=pd.read_excel(r"C:\Users\Tanaka\Desktop\Attachment\Unclean_Enterprises.xlsx")

# %%
data
# Out:
#         id           Name    Surname    Enterprise Name   District  \
# 0        3         George  Chakawora   George Chakawora  Goromonzi
# 1        6          Viola     Bhosvo                VSV  Goromonzi
# 2        7          Vesta       Samu                VSV  Goromonzi
# 3        8  Timothy Sasha    Matambo                VSV  Goromonzi
# 4        9        Kudzayi     Gweshe  Kudzai Joy Gweshe  Goromonzi
# ...    ...            ...        ...                ...        ...
# 2008  2034      Elizabeth    Musindo  Elizabeth Musindo   Chikomba
# 2009  2035        Jenipha  Zvinorova  Jenipha Zvinorova   Chikomba
# 2010  2036       Loveness     Mutsau    Loveness Mutsau   Chikomba
# 2011  2037         Sandra    gwasira     Sandra Gwasira   Chikomba
# 2012  2038       Tichaona     Tineyi    Tichaona Tineyi   Chikomba
#
#                Start date       Sector               Value  Turnover  \
# 0     2020-08-01 00:00:00  Agriculture  Poultry Production      4800
# ...

# %%
data.isnull()
# Out:
#          id   Name  Surname  Enterprise Name  District  Start date  Sector  \
# 0     False  False    False            False     False       False   False
# 1     False  False    False            False     False       False   False
# 2     False  False    False            False     False       False   False
# 3     False  False    False            False     False       False   False
# 4     False  False    False            False     False       False   False
# ...     ...    ...      ...              ...       ...         ...     ...
# 2008  False  False    False            False     False       False   False
# 2009  False  False    False            False     False       False   False
# 2010  False  False    False            False     False       False   False
# 2011  False  False    False            False     False       False   False
# 2012  False  False    False            False     False       False   False
#
# ...

# %%
data.isna().sum()
# Out:
# id                      0
# Name                    0
# Surname                 0
# Enterprise Name         6
# District                0
# Start date              0
# Sector                  3
# Value                   1
# Turnover                0
# Employees               0
# Support                 3
# Financial support      72
# Training support        1
# Time                    0
# LSP                     0
# DOB                    11
# Sex                    11
# Registered            742
# non OYE employees       0
# Monthly Income          0
# Reg Date              730
# y Youth Ages          730
# Enterprise Status     733
# Functional Date      1187
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013 entries, 0 to 2012
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2013 non-null   int64
#  1   Name               2013 non-null   object
#  2   Surname            2013 non-null   object
#  3   Enterprise Name    2007 non-null   object
#  4   District           2013 non-null   object
#  5   Start date         2013 non-null   object
#  6   Sector             2010 non-null   object
#  7   Value              2012 non-null   object
#  8   Turnover           2013 non-null   int64
#  9   Employees          2013 non-null   int64
#  10  Support            2010 non-null   object
#  11  Financial support  1941 non-null   object
#  12  Training support   2012 non-null   object
#  13  Time               2013 non-null   int64
#  14  LSP                2013 non-null   object
#  15  DOB                2002 non-null   object
# ...

# %%
data.describe()
# Out:
#                 id      Turnover    Employees          Time  \
# count  2013.000000   2013.000000  2013.000000  2.013000e+03
# mean   1030.581222    322.245405     7.548932  1.644060e+09
# std     582.757182    515.363410    30.035288  9.880399e+06
# min       3.000000      0.000000     0.000000  1.619859e+09
# 25%     527.000000      0.000000     0.000000  1.637106e+09
# 50%    1030.000000    240.000000     1.000000  1.639472e+09
# 75%    1535.000000    480.000000     3.000000  1.649241e+09
# max    2038.000000  11520.000000  1000.000000  1.674570e+09
#
#        non OYE employees  Monthly Income
# count        2013.000000     2013.000000
# mean            0.408843       12.801292
# std             4.620301       34.376399
# min             0.000000        0.000000
# 25%             0.000000        0.000000
# 50%             0.000000        0.000000
# 75%             0.000000       25.000000
# max           200.000000      960.000000

# %%
pd.DataFrame(data["Value"].value_counts())
# Out:
#                          Value
# na                         398
# Poultry                    207
# horticulture               172
# Horticulture               119
# Horticulture Production     82
# ...                        ...
# Goat Production              1
# GOAT FARMING                 1
# goat farming                 1
# Cosmetics                    1
# Horticulture Produce         1
#
# [180 rows x 1 columns]

# %%
pd.DataFrame(data["Turnover"].value_counts())
# Out:
#       Turnover
# 0          760
# 360        233
# 600        115
# 300        110
# 480         66
# ...        ...
# 270          1
# 20           1
# 45           1
# 4100         1
# 4800         1
#
# [83 rows x 1 columns]

# %%
pd.DataFrame(data["Sector"].value_counts())
# Out:
#              Sector
# Agriculture    1904
# Energy           53
# Green Jobs       52
# WASH              1

# %%
pd.DataFrame(data["LSP"].value_counts())
# Out:
#                       LSP
# Green Impact          987
# Boost Fellowship      584
# Proweb                130
# Empretec              108
# RCSR                   88
# Women In Agriculture   71
# SNV                    39
# Women in Agriculture    6

# %%
pd.DataFrame(data["Sex"].value_counts())
# Out:
#          Sex
# female  1104
# male     897
# Female     1

# %%
pd.DataFrame(data["Registered"].value_counts())
# Out:
#      Registered
# No         1064
# Yes         207

# %%
sns.heatmap(data.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.isnull(), yticklabels=False, annot=True)
# Out:
# <AxesSubplot:>

# %%
data.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'Turnover'}>],
#        [<AxesSubplot:title={'center':'Employees'}>,
#         <AxesSubplot:title={'center':'Time'}>],
#        [<AxesSubplot:title={'center':'non OYE employees'}>,
#         <AxesSubplot:title={'center':'Monthly Income'}>]], dtype=object)

# %%
pd.DataFrame(data["Value"].value_counts()).plot(kind="bar", figsize=(20,10))
# Out:
# <AxesSubplot:>
